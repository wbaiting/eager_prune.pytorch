# %%
import torch
fc = torch.nn.Linear(120,84)

# %%
for c in fc.named_parameters():
    print(c)
fc.in_features
# Out:
# ('weight', Parameter containing:
# tensor([[-0.0667,  0.0344, -0.0814,  ...,  0.0302, -0.0892,  0.0015],
#         [ 0.0412,  0.0890, -0.0430,  ...,  0.0111, -0.0866, -0.0030],
#         [ 0.0546, -0.0364,  0.0118,  ..., -0.0734,  0.0212, -0.0878],
#         ...,
#         [ 0.0713,  0.0010,  0.0745,  ..., -0.0101, -0.0637, -0.0737],
#         [-0.0727, -0.0453, -0.0220,  ...,  0.0789, -0.0238, -0.0683],
#         [ 0.0194,  0.0455, -0.0202,  ..., -0.0337,  0.0452, -0.0394]],
#        requires_grad=True))
# ('bias', Parameter containing:
# tensor([-0.0722, -0.0120, -0.0069, -0.0179,  0.0764, -0.0489,  0.0673, -0.0174,
#         -0.0822, -0.0740, -0.0254, -0.0179,  0.0694, -0.0372,  0.0546, -0.0892,
#          0.0851,  0.0243,  0.0112, -0.0160, -0.0730, -0.0296, -0.0503, -0.0686,
#          0.0674, -0.0676, -0.0413, -0.0499, -0.0816, -0.0524,  0.0911,  0.0250,
#          0.0243, -0.0846, -0.0378, -0.0380, -0.0630,  0.0447, -0.0389,  0.0313,
# ...

# %%
# !nvidia-smi
# Out:
# Wed Jul 22 18:00:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.104      Driver Version: 410.104      CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM3...  On   | 00000000:34:00.0 Off |                    0 |
# | N/A   32C    P0    50W / 350W |      0MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM3...  On   | 00000000:36:00.0 Off |                    0 |
# | N/A   30C    P0    49W / 350W |      0MiB / 32480MiB |      0%      Default |
# ...
